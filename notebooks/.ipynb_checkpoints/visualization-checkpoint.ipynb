# %%
# %% [markdown]
"""
# TransUNet肾脏分割可视化

本脚本提供以下功能：
1. 加载预训练的TransUNet模型
2. 执行单张图像推理
3. 应用后处理优化分割结果
4. 可视化原始图像、真实标签、预测结果对比
5. 计算定量评估指标
"""

# %%
import sys
import os
sys.path.append('/root/TransUNet_fusion')  # 添加项目根目录到Python路径
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2
import scipy.io as sio
from PIL import Image
from networks.vit_seg_modeling import VisionTransformer_mixRf as ViT_seg_mixRf
from networks.vit_seg_modeling import CONFIGS as CONFIGS_ViT_seg
from torchvision import transforms
# %% [markdown]
"""
## 1. 后处理函数定义
"""
# %%
def remove_small_regions(mask, min_area=500):
    """去除小面积不连通区域"""
    mask = (mask * 255).astype(np.uint8)
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask, connectivity=8)
    cleaned_mask = np.zeros_like(mask)
    for i in range(1, num_labels):
        if stats[i, cv2.CC_STAT_AREA] >= min_area:
            cleaned_mask[labels == i] = 255
    return cleaned_mask.astype(float) / 255.0

def fill_holes(mask):
    """填充掩码中的孔洞"""
    mask = (mask * 255).astype(np.uint8)
    contours, hierarchy = cv2.findContours(mask, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        for i, contour in enumerate(contours):
            if hierarchy[0][i][3] != -1:  # 孔洞检测
                cv2.drawContours(mask, [contour], 0, 255, -1)
    return mask.astype(float) / 255.0
    
def make_convex(mask):
    """
    将掩码转换为凸形。
    :param mask: 输入掩码（二值图像，0 或 1）。
    :return: 凸形掩码。
    """
    # 转换为uint8
    mask = (mask * 255).astype(np.uint8)
    
    # 找到外部轮廓
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # 创建一个空白掩码
    convex_mask = np.zeros_like(mask)
    
    # 计算凸包并填充
    for contour in contours:
        hull = cv2.convexHull(contour)
        cv2.drawContours(convex_mask, [hull], 0, 255, -1)
    
    return convex_mask.astype(float) / 255.0
    
def postprocess_mask(pred_mask, min_area=500):
    """完整后处理流程"""
    mask = (pred_mask > 0.5).astype(float)
    mask = remove_small_regions(mask, min_area)
    mask = fill_holes(mask)
    mask = make_convex(mask)
    return mask

# %% [markdown]
"""
## 2. 模型加载与初始化
"""
# %%
def load_transunet_model(model_path, img_size=224):
    """加载预训练的TransUNet模型"""
    config = CONFIGS_ViT_seg['R50-ViT-B_16']
    config.n_classes = 1
    config.n_skip = 3
    config.patches.grid = (int(img_size / 16), int(img_size / 16))
    
    model = ViT_seg_mixRf(config, img_size=img_size, num_classes=config.n_classes)
    model.load_state_dict(torch.load(model_path))
    model.cuda()
    model.eval()
    return model

# 配置路径
MODEL_PATH = "/root/TransUNet_fusion/new_model/ours (only image)1/best_model.pth"
DATA_DIR = "/root/autodl-tmp/data/imgs"
MASK_DIR = "/root/autodl-tmp/data/binary_masks"
RF_DIR = "/root/autodl-tmp/data/rfs"
OUTPUT_DIR = "/root/TransUNet_fusion/only_image_visualization"
RESULTS_TXT = os.path.join(OUTPUT_DIR, "results_summary.txt")  # 新增结果文件路径
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
"""
## 3. 数据预处理
"""
# %%
def preprocess_image(image_path, img_size=224):
    img_transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5], std=[0.5])
    ])
    img = Image.open(image_path).convert('L')
    img = np.array(img)
    img = img_transform(img)
    img = img.unsqueeze(0).cuda()  # (1, 1, H, W)
    return img

def load_ground_truth(mask_path, img_size=224):
    mask = Image.open(mask_path).convert('L')
    mask = mask.resize((img_size, img_size))
    mask = np.array(mask) > 0
    return mask.astype(np.float32)

# %% [markdown]
"""
## 4. 推理与可视化
"""
# %%
def visualize_results(image, true_mask, pred_mask, processed_mask, save_path=None):

    plt.figure(figsize=(18, 6))
    
    plt.subplot(1, 4, 1)
    plt.imshow(image, cmap='gray')
    plt.title("Input Image")
    plt.axis('off')
    
    plt.subplot(1, 4, 2)
    plt.imshow(true_mask, cmap='gray')
    plt.title("Ground Truth")
    plt.axis('off')
    
    plt.subplot(1, 4, 3)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Raw Prediction")
    plt.axis('off')
    
    plt.subplot(1, 4, 4)
    plt.imshow(processed_mask, cmap='gray')
    plt.title("Post-processed")
    plt.axis('off')
    
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.show()

# %% [markdown]
"""
## 5. 评估指标计算
"""
# %%
def calculate_metrics(true_mask, pred_mask):
    
    y_true = true_mask.astype(bool)
    y_pred = pred_mask.astype(bool)
    
    tp = np.sum(y_true & y_pred)
    fp = np.sum(~y_true & y_pred)
    fn = np.sum(y_true & ~y_pred)
    
    precision = tp / (tp + fp + 1e-10)
    recall = tp / (tp + fn + 1e-10)
    dice = 2 * tp / (2 * tp + fp + fn + 1e-10)
    
    # print(f"\nEvaluation Metrics:")
    print(f"Dice Score: {dice:.4f}")
    # print(f"Precision: {precision:.4f}")
    # print(f"Recall: {recall:.4f}")
    return dice
    
def dice_score(y_true, y_pred):
    intersection = np.sum(y_true * y_pred)
    union = np.sum(y_true) + np.sum(y_pred)
    dice = (2. * intersection) / (union + 1e-7)
    print(f"Dice Score: {dice:.4f}")
    return dice
"""
## 6. 主执行流程
"""
# %%
# 加载模型
model = load_transunet_model(MODEL_PATH)
    
# 获取测试样本
test_images = sorted([f for f in os.listdir(DATA_DIR) if f.endswith('.jpg')])
test_masks = sorted([f for f in os.listdir(MASK_DIR) if f.endswith('.png')])
test_rfs = sorted([f for f in os.listdir(RF_DIR) if f.endswith('.mat')]
                 )
def load_rf_image(rfimg_path, img_size=224):
    """加载并处理RF图像（保持单通道），返回归一化后的RF数据和tensor"""
    rf_transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ])
    mat_data = sio.loadmat(rfimg_path)
    frameRF = mat_data['frameRF']
    rf_data = frameRF[0]['data'][0]
    
    rf_data = np.abs(rf_data)
    rf_data = np.log(rf_data + 1e-6)
    
    rf_data = (rf_data - rf_data.min()) / (rf_data.max() - rf_data.min() + 1e-6)
    rf_data = torch.from_numpy(rf_data).float()
    rf_data = rf_data.unsqueeze(0)
    rf_tensor = rf_transform(rf_data)
    rf_tensor = rf_tensor.unsqueeze(0).cuda()
    return rf_tensor
    
def load_original_image_mask(img_path, mask_path, rf_path):
    """加载原始尺寸的图像和掩码"""
    img = Image.open(img_path).convert('L')
    mask = Image.open(mask_path).convert('L')
    original_size = img.size
    
    img_np = np.array(img)
    mask_np = (np.array(mask) > 0).astype(np.float32)
    
    return img_np, mask_np, original_size

def resize_mask(mask, target_size):
    mask_img = Image.fromarray((mask * 255).astype(np.uint8))
    
    resized_img = mask_img.resize(target_size, Image.LANCZOS)
    
    return (np.array(resized_img) > 127).astype(np.float32)

total_dice = 0
with open(RESULTS_TXT, 'w') as f:
    f.write("Image Name\tDice Score\n")
    f.write("------------------------\n")
for img_name, mask_name, rf_name in zip(test_images, test_masks, test_rfs):
    img_path = os.path.join(DATA_DIR, img_name)
    mask_path = os.path.join(MASK_DIR, mask_name)
    rf_path = os.path.join(RF_DIR, rf_name)
    print(img_path)
    original_img, original_mask, original_size = load_original_image_mask(img_path, mask_path, rf_path)
    
    img_tensor = preprocess_image(img_path)
    rf_tensor = load_rf_image(rf_path)

    with torch.no_grad():
        pred = model(img_tensor, None)
        # rf_aligned = model.rf_stn(rf_tensor).cpu().squeeze()
        pred_mask = torch.sigmoid(pred).squeeze().cpu().numpy()
    
    pred_mask_original_size = resize_mask(pred_mask > 0.5, original_size)
    processed_mask_original_size = postprocess_mask(pred_mask_original_size)
    
    # 可视化（原始尺寸）
    save_path = os.path.join(OUTPUT_DIR, f"result_{os.path.splitext(img_name)[0]}.png")
    # visualize_results(original_img, 
    #                 original_mask, 
    #                 pred_mask_original_size, 
    #                 processed_mask_original_size,
    #                 save_path)
    
    print(f"\nOriginal Size Results for {img_name}:")

    dice = calculate_metrics(original_mask, pred_mask_original_size)
    total_dice += dice
    with open(RESULTS_TXT, 'a') as f:
        f.write(f"{img_name}\t{dice:.4f}\n")
    # 保存原始尺寸预测结果
    cv2.imwrite(
        os.path.join(OUTPUT_DIR, f"pred_{img_name}"), 
        (pred_mask_original_size * 255).astype(np.uint8)
    )
mean_dice = total_dice / len(test_images)
print("Evaluation Finished: Dice Score is ", mean_dice)
# Out:
# /root/miniconda3/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /root/autodl-tmp/new_test_dataset/imgs/OCHADNGK.jpg
#
# Original Size Results for OCHADNGK.jpg:
# Dice Score: 0.9620
# /root/autodl-tmp/new_test_dataset/imgs/OCHADNP4.jpg
#
# Original Size Results for OCHADNP4.jpg:
# Dice Score: 0.9465
# /root/autodl-tmp/new_test_dataset/imgs/OCHALB1C.jpg
#
# Original Size Results for OCHALB1C.jpg:
# Dice Score: 0.9649
# /root/autodl-tmp/new_test_dataset/imgs/OCHALB1G.jpg
#
# Original Size Results for OCHALB1G.jpg:
# Dice Score: 0.9538
# /root/autodl-tmp/new_test_dataset/imgs/OCHALB1K.jpg
#
# Original Size Results for OCHALB1K.jpg:
# Dice Score: 0.9515
# /root/autodl-tmp/new_test_dataset/imgs/OCHF8JA8.jpg
#
# Original Size Results for OCHF8JA8.jpg:
# Dice Score: 0.8036
# /root/autodl-tmp/new_test_dataset/imgs/OCHF8JAC.jpg
#
# Original Size Results for OCHF8JAC.jpg:
# Dice Score: 0.8353
# /root/autodl-tmp/new_test_dataset/imgs/OCHF8JAI.jpg
#
# Original Size Results for OCHF8JAI.jpg:
# Dice Score: 0.8964
# /root/autodl-tmp/new_test_dataset/imgs/OCHF8JAM.jpg
#
# Original Size Results for OCHF8JAM.jpg:
# Dice Score: 0.8588
# /root/autodl-tmp/new_test_dataset/imgs/OCHFHDQU.jpg
#
# Original Size Results for OCHFHDQU.jpg:
# Dice Score: 0.9222
# /root/autodl-tmp/new_test_dataset/imgs/OCHFHDR2.jpg
#
# Original Size Results for OCHFHDR2.jpg:
# Dice Score: 0.9483
# /root/autodl-tmp/new_test_dataset/imgs/OCHFHDR6.jpg
#
# Original Size Results for OCHFHDR6.jpg:
# Dice Score: 0.9289
# /root/autodl-tmp/new_test_dataset/imgs/OCHFHDRC.jpg
#
# Original Size Results for OCHFHDRC.jpg:
# Dice Score: 0.9240
# /root/autodl-tmp/new_test_dataset/imgs/OCI8KD0K.jpg
#
# Original Size Results for OCI8KD0K.jpg:
# Dice Score: 0.9052
# /root/autodl-tmp/new_test_dataset/imgs/OCI8KD0O.jpg
#
# Original Size Results for OCI8KD0O.jpg:
# Dice Score: 0.8763
# /root/autodl-tmp/new_test_dataset/imgs/OCI8KD0U.jpg
#
# Original Size Results for OCI8KD0U.jpg:
# Dice Score: 0.9304
# /root/autodl-tmp/new_test_dataset/imgs/OCI8KD92.jpg
#
# Original Size Results for OCI8KD92.jpg:
# Dice Score: 0.8849
# /root/autodl-tmp/new_test_dataset/imgs/OCI8MGHC.jpg
#
# Original Size Results for OCI8MGHC.jpg:
# Dice Score: 0.9226
# /root/autodl-tmp/new_test_dataset/imgs/OCI8MGHG.jpg
#
# Original Size Results for OCI8MGHG.jpg:
# Dice Score: 0.9109
# /root/autodl-tmp/new_test_dataset/imgs/OCI8MGPK.jpg
#
# Original Size Results for OCI8MGPK.jpg:
# Dice Score: 0.9138
# /root/autodl-tmp/new_test_dataset/imgs/OCI8MGPO.jpg
#
# Original Size Results for OCI8MGPO.jpg:
# Dice Score: 0.8563
# /root/autodl-tmp/new_test_dataset/imgs/OCI9IMJK.jpg
#
# Original Size Results for OCI9IMJK.jpg:
# Dice Score: 0.9206
# /root/autodl-tmp/new_test_dataset/imgs/OCI9IMJO.jpg
#
# Original Size Results for OCI9IMJO.jpg:
# Dice Score: 0.8405
# /root/autodl-tmp/new_test_dataset/imgs/OCI9IMK8.jpg
#
# Original Size Results for OCI9IMK8.jpg:
# Dice Score: 0.9319
# /root/autodl-tmp/new_test_dataset/imgs/OCI9IMKC.jpg
#
# Original Size Results for OCI9IMKC.jpg:
# Dice Score: 0.8136
# /root/autodl-tmp/new_test_dataset/imgs/OCI9SGCO.jpg
#
# Original Size Results for OCI9SGCO.jpg:
# Dice Score: 0.9516
# /root/autodl-tmp/new_test_dataset/imgs/OCI9SGCS.jpg
#
# Original Size Results for OCI9SGCS.jpg:
# Dice Score: 0.9578
# /root/autodl-tmp/new_test_dataset/imgs/OCI9SGD8.jpg
#
# Original Size Results for OCI9SGD8.jpg:
# Dice Score: 0.9372
# /root/autodl-tmp/new_test_dataset/imgs/OCIAIG66.jpg
#
# Original Size Results for OCIAIG66.jpg:
# Dice Score: 0.8662
# /root/autodl-tmp/new_test_dataset/imgs/OCIAIG82.jpg
#
# Original Size Results for OCIAIG82.jpg:
# Dice Score: 0.7525
# /root/autodl-tmp/new_test_dataset/imgs/OCIAIG8E.jpg
#
# Original Size Results for OCIAIG8E.jpg:
# Dice Score: 0.8575
# /root/autodl-tmp/new_test_dataset/imgs/OCIAIG8I.jpg
#
# Original Size Results for OCIAIG8I.jpg:
# Dice Score: 0.8915
# /root/autodl-tmp/new_test_dataset/imgs/P1Q92O8A.jpg
#
# Original Size Results for P1Q92O8A.jpg:
# Dice Score: 0.8763
# /root/autodl-tmp/new_test_dataset/imgs/P27AJ4II.jpg
#
# Original Size Results for P27AJ4II.jpg:
# Dice Score: 0.9467
# /root/autodl-tmp/new_test_dataset/imgs/P27AJ4IS.jpg
#
# Original Size Results for P27AJ4IS.jpg:
# Dice Score: 0.9449
# /root/autodl-tmp/new_test_dataset/imgs/P2EEJTP2.jpg
#
# Original Size Results for P2EEJTP2.jpg:
# Dice Score: 0.9406
# /root/autodl-tmp/new_test_dataset/imgs/P2EEJTP4.jpg
#
# Original Size Results for P2EEJTP4.jpg:
# Dice Score: 0.8727
# /root/autodl-tmp/new_test_dataset/imgs/P2HB233Q.jpg
#
# Original Size Results for P2HB233Q.jpg:
# Dice Score: 0.9303
# /root/autodl-tmp/new_test_dataset/imgs/P2K8O3H6.jpg
#
# Original Size Results for P2K8O3H6.jpg:
# Dice Score: 0.9422
# /root/autodl-tmp/new_test_dataset/imgs/P2K8O3HI.jpg
#
# Original Size Results for P2K8O3HI.jpg:
# Dice Score: 0.9245
# /root/autodl-tmp/new_test_dataset/imgs/P2KAOS3C.jpg
#
# Original Size Results for P2KAOS3C.jpg:
# Dice Score: 0.9271
# /root/autodl-tmp/new_test_dataset/imgs/P2KAOS3M.jpg
#
# Original Size Results for P2KAOS3M.jpg:
# Dice Score: 0.9440
# /root/autodl-tmp/new_test_dataset/imgs/P2KBNKK2.jpg
#
# Original Size Results for P2KBNKK2.jpg:
# Dice Score: 0.9366
# /root/autodl-tmp/new_test_dataset/imgs/P2KBNKKE.jpg
#
# Original Size Results for P2KBNKKE.jpg:
# Dice Score: 0.9464
# /root/autodl-tmp/new_test_dataset/imgs/P338O00A.jpg
#
# Original Size Results for P338O00A.jpg:
# Dice Score: 0.9247
# /root/autodl-tmp/new_test_dataset/imgs/P338O00M.jpg
#
# Original Size Results for P338O00M.jpg:
# Dice Score: 0.9385
# /root/autodl-tmp/new_test_dataset/imgs/P33AD4L0.jpg
#
# Original Size Results for P33AD4L0.jpg:
# Dice Score: 0.9390
# /root/autodl-tmp/new_test_dataset/imgs/P33AD4LC.jpg
#
# Original Size Results for P33AD4LC.jpg:
# Dice Score: 0.9661
# /root/autodl-tmp/new_test_dataset/imgs/P359OT3M.jpg
#
# Original Size Results for P359OT3M.jpg:
# Dice Score: 0.9465
# /root/autodl-tmp/new_test_dataset/imgs/P359OT42.jpg
#
# Original Size Results for P359OT42.jpg:
# Dice Score: 0.9487
# /root/autodl-tmp/new_test_dataset/imgs/P429AE3S.jpg
#
# Original Size Results for P429AE3S.jpg:
# Dice Score: 0.9436
# /root/autodl-tmp/new_test_dataset/imgs/P429AE3U.jpg
#
# Original Size Results for P429AE3U.jpg:
# Dice Score: 0.9535
# /root/autodl-tmp/new_test_dataset/imgs/P429AE4E.jpg
#
# Original Size Results for P429AE4E.jpg:
# Dice Score: 0.9445
# /root/autodl-tmp/new_test_dataset/imgs/P42ALLHA.jpg
#
# Original Size Results for P42ALLHA.jpg:
# Dice Score: 0.9171
# /root/autodl-tmp/new_test_dataset/imgs/P42ALLHC.jpg
#
# Original Size Results for P42ALLHC.jpg:
# Dice Score: 0.9469
# /root/autodl-tmp/new_test_dataset/imgs/P42ALLHQ.jpg
#
# Original Size Results for P42ALLHQ.jpg:
# Dice Score: 0.9362
# /root/autodl-tmp/new_test_dataset/imgs/P42ALLHS.jpg
#
# Original Size Results for P42ALLHS.jpg:
# Dice Score: 0.9468
# /root/autodl-tmp/new_test_dataset/imgs/P42BN1BI.jpg
#
# Original Size Results for P42BN1BI.jpg:
# Dice Score: 0.9351
# /root/autodl-tmp/new_test_dataset/imgs/P42BN1BK.jpg
#
# Original Size Results for P42BN1BK.jpg:
# Dice Score: 0.9036
# /root/autodl-tmp/new_test_dataset/imgs/P42EJ788.jpg
#
# Original Size Results for P42EJ788.jpg:
# Dice Score: 0.9252
# /root/autodl-tmp/new_test_dataset/imgs/P42EJ78A.jpg
#
# Original Size Results for P42EJ78A.jpg:
# Dice Score: 0.9331
# /root/autodl-tmp/new_test_dataset/imgs/P42EJ78O.jpg
#
# Original Size Results for P42EJ78O.jpg:
# Dice Score: 0.8800
# /root/autodl-tmp/new_test_dataset/imgs/P42EJ78Q.jpg
#
# Original Size Results for P42EJ78Q.jpg:
# Dice Score: 0.9631
# /root/autodl-tmp/new_test_dataset/imgs/P4AF61A4.jpg
#
# Original Size Results for P4AF61A4.jpg:
# Dice Score: 0.9540
# /root/autodl-tmp/new_test_dataset/imgs/P4AF61A6.jpg
#
# Original Size Results for P4AF61A6.jpg:
# Dice Score: 0.9543
# /root/autodl-tmp/new_test_dataset/imgs/P4AF61IM.jpg
#
# Original Size Results for P4AF61IM.jpg:
# Dice Score: 0.9678
# /root/autodl-tmp/new_test_dataset/imgs/P4AF61IO.jpg
#
# Original Size Results for P4AF61IO.jpg:
# Dice Score: 0.9462
# /root/autodl-tmp/new_test_dataset/imgs/P4B8JPO8.jpg
#
# Original Size Results for P4B8JPO8.jpg:
# Dice Score: 0.9513
# /root/autodl-tmp/new_test_dataset/imgs/P4B8JPOA.jpg
#
# Original Size Results for P4B8JPOA.jpg:
# Dice Score: 0.9420
# /root/autodl-tmp/new_test_dataset/imgs/P4B8JPOO.jpg
#
# Original Size Results for P4B8JPOO.jpg:
# Dice Score: 0.9391
# /root/autodl-tmp/new_test_dataset/imgs/P4B8JPOQ.jpg
#
# Original Size Results for P4B8JPOQ.jpg:
# Dice Score: 0.9516
# /root/autodl-tmp/new_test_dataset/imgs/P599DL8G.jpg
#
# Original Size Results for P599DL8G.jpg:
# Dice Score: 0.9384
# /root/autodl-tmp/new_test_dataset/imgs/P599DL8I.jpg
#
# Original Size Results for P599DL8I.jpg:
# Dice Score: 0.9490
# /root/autodl-tmp/new_test_dataset/imgs/P599DL8K.jpg
#
# Original Size Results for P599DL8K.jpg:
# Dice Score: 0.9567
# /root/autodl-tmp/new_test_dataset/imgs/P599DL8M.jpg
#
# Original Size Results for P599DL8M.jpg:
# Dice Score: 0.9563
# /root/autodl-tmp/new_test_dataset/imgs/P599DL8O.jpg
#
# Original Size Results for P599DL8O.jpg:
# Dice Score: 0.9442
# /root/autodl-tmp/new_test_dataset/imgs/P599DL8Q.jpg
#
# Original Size Results for P599DL8Q.jpg:
# Dice Score: 0.9364
# /root/autodl-tmp/new_test_dataset/imgs/P599DL98.jpg
#
# Original Size Results for P599DL98.jpg:
# Dice Score: 0.9145
# /root/autodl-tmp/new_test_dataset/imgs/P599DL9A.jpg
#
# Original Size Results for P599DL9A.jpg:
# Dice Score: 0.9463
# /root/autodl-tmp/new_test_dataset/imgs/P599DL9C.jpg
#
# Original Size Results for P599DL9C.jpg:
# Dice Score: 0.9580
# /root/autodl-tmp/new_test_dataset/imgs/P599DL9E.jpg
#
# Original Size Results for P599DL9E.jpg:
# Dice Score: 0.9710
# /root/autodl-tmp/new_test_dataset/imgs/P599DL9G.jpg
#
# Original Size Results for P599DL9G.jpg:
# Dice Score: 0.9710
# /root/autodl-tmp/new_test_dataset/imgs/P599DL9I.jpg
#
# Original Size Results for P599DL9I.jpg:
# Dice Score: 0.9677
# /root/autodl-tmp/new_test_dataset/imgs/P599MUPS.jpg
#
# Original Size Results for P599MUPS.jpg:
# Dice Score: 0.9564
# /root/autodl-tmp/new_test_dataset/imgs/P599MUPU.jpg
#
# Original Size Results for P599MUPU.jpg:
# Dice Score: 0.9458
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQ0.jpg
#
# Original Size Results for P599MUQ0.jpg:
# Dice Score: 0.9393
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQ2.jpg
#
# Original Size Results for P599MUQ2.jpg:
# Dice Score: 0.9403
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQ4.jpg
#
# Original Size Results for P599MUQ4.jpg:
# Dice Score: 0.9541
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQ6.jpg
#
# Original Size Results for P599MUQ6.jpg:
# Dice Score: 0.9537
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQK.jpg
#
# Original Size Results for P599MUQK.jpg:
# Dice Score: 0.9530
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQM.jpg
#
# Original Size Results for P599MUQM.jpg:
# Dice Score: 0.9498
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQO.jpg
#
# Original Size Results for P599MUQO.jpg:
# Dice Score: 0.9574
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQQ.jpg
#
# Original Size Results for P599MUQQ.jpg:
# Dice Score: 0.9591
# /root/autodl-tmp/new_test_dataset/imgs/P599MUQS.jpg
#
# Original Size Results for P599MUQS.jpg:
# Dice Score: 0.9678
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3C.jpg
#
# Original Size Results for P599QB3C.jpg:
# Dice Score: 0.9555
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3E.jpg
#
# Original Size Results for P599QB3E.jpg:
# Dice Score: 0.9540
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3G.jpg
#
# Original Size Results for P599QB3G.jpg:
# Dice Score: 0.9570
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3I.jpg
#
# Original Size Results for P599QB3I.jpg:
# Dice Score: 0.9595
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3K.jpg
#
# Original Size Results for P599QB3K.jpg:
# Dice Score: 0.9455
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3M.jpg
#
# Original Size Results for P599QB3M.jpg:
# Dice Score: 0.9536
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3O.jpg
#
# Original Size Results for P599QB3O.jpg:
# Dice Score: 0.9537
# /root/autodl-tmp/new_test_dataset/imgs/P599QB3Q.jpg
#
# Original Size Results for P599QB3Q.jpg:
# Dice Score: 0.9638
# /root/autodl-tmp/new_test_dataset/imgs/P599QB48.jpg
#
# Original Size Results for P599QB48.jpg:
# Dice Score: 0.9549
# /root/autodl-tmp/new_test_dataset/imgs/P599QB4A.jpg
#
# Original Size Results for P599QB4A.jpg:
# Dice Score: 0.9500
# /root/autodl-tmp/new_test_dataset/imgs/P599QB4C.jpg
#
# Original Size Results for P599QB4C.jpg:
# Dice Score: 0.9510
# /root/autodl-tmp/new_test_dataset/imgs/P599QB4E.jpg
#
# Original Size Results for P599QB4E.jpg:
# Dice Score: 0.9561
# /root/autodl-tmp/new_test_dataset/imgs/P599QB4G.jpg
#
# Original Size Results for P599QB4G.jpg:
# Dice Score: 0.9628
# /root/autodl-tmp/new_test_dataset/imgs/P599QB4I.jpg
#
# Original Size Results for P599QB4I.jpg:
# Dice Score: 0.9540
# /root/autodl-tmp/new_test_dataset/imgs/P599QB4K.jpg
#
# Original Size Results for P599QB4K.jpg:
# Dice Score: 0.9517
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HL2.jpg
#
# Original Size Results for P59A2HL2.jpg:
# Dice Score: 0.9177
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HL4.jpg
#
# Original Size Results for P59A2HL4.jpg:
# Dice Score: 0.9197
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HL6.jpg
#
# Original Size Results for P59A2HL6.jpg:
# Dice Score: 0.9510
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HL8.jpg
#
# Original Size Results for P59A2HL8.jpg:
# Dice Score: 0.9574
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HLA.jpg
#
# Original Size Results for P59A2HLA.jpg:
# Dice Score: 0.9439
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HLE.jpg
#
# Original Size Results for P59A2HLE.jpg:
# Dice Score: 0.9565
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HLG.jpg
#
# Original Size Results for P59A2HLG.jpg:
# Dice Score: 0.9643
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HLI.jpg
#
# Original Size Results for P59A2HLI.jpg:
# Dice Score: 0.9461
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HLK.jpg
#
# Original Size Results for P59A2HLK.jpg:
# Dice Score: 0.9606
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HLM.jpg
#
# Original Size Results for P59A2HLM.jpg:
# Dice Score: 0.9530
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HM4.jpg
#
# Original Size Results for P59A2HM4.jpg:
# Dice Score: 0.9448
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HM6.jpg
#
# Original Size Results for P59A2HM6.jpg:
# Dice Score: 0.9432
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HO0.jpg
#
# Original Size Results for P59A2HO0.jpg:
# Dice Score: 0.9464
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HO2.jpg
#
# Original Size Results for P59A2HO2.jpg:
# Dice Score: 0.9412
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HO4.jpg
#
# Original Size Results for P59A2HO4.jpg:
# Dice Score: 0.9493
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HO6.jpg
#
# Original Size Results for P59A2HO6.jpg:
# Dice Score: 0.9368
# /root/autodl-tmp/new_test_dataset/imgs/P59A2HO8.jpg
#
# Original Size Results for P59A2HO8.jpg:
# Dice Score: 0.9481
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EGK.jpg
#
# Original Size Results for P59A6EGK.jpg:
# Dice Score: 0.9420
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EGM.jpg
#
# Original Size Results for P59A6EGM.jpg:
# Dice Score: 0.9547
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EGO.jpg
#
# Original Size Results for P59A6EGO.jpg:
# Dice Score: 0.9534
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EGQ.jpg
#
# Original Size Results for P59A6EGQ.jpg:
# Dice Score: 0.9304
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EGS.jpg
#
# Original Size Results for P59A6EGS.jpg:
# Dice Score: 0.9546
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EGU.jpg
#
# Original Size Results for P59A6EGU.jpg:
# Dice Score: 0.9405
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EH0.jpg
#
# Original Size Results for P59A6EH0.jpg:
# Dice Score: 0.9595
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EH2.jpg
#
# Original Size Results for P59A6EH2.jpg:
# Dice Score: 0.9667
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EH8.jpg
#
# Original Size Results for P59A6EH8.jpg:
# Dice Score: 0.9604
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EHA.jpg
#
# Original Size Results for P59A6EHA.jpg:
# Dice Score: 0.9656
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EHC.jpg
#
# Original Size Results for P59A6EHC.jpg:
# Dice Score: 0.9542
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EHE.jpg
#
# Original Size Results for P59A6EHE.jpg:
# Dice Score: 0.9488
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EHG.jpg
#
# Original Size Results for P59A6EHG.jpg:
# Dice Score: 0.9491
# /root/autodl-tmp/new_test_dataset/imgs/P59A6EHI.jpg
#
# Original Size Results for P59A6EHI.jpg:
# Dice Score: 0.9402
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2A0.jpg
#
# Original Size Results for P59AA2A0.jpg:
# Dice Score: 0.9614
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2A2.jpg
#
# Original Size Results for P59AA2A2.jpg:
# Dice Score: 0.9390
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2A4.jpg
#
# Original Size Results for P59AA2A4.jpg:
# Dice Score: 0.9459
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2A6.jpg
#
# Original Size Results for P59AA2A6.jpg:
# Dice Score: 0.9446
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2A8.jpg
#
# Original Size Results for P59AA2A8.jpg:
# Dice Score: 0.9470
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2AA.jpg
#
# Original Size Results for P59AA2AA.jpg:
# Dice Score: 0.9397
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2AC.jpg
#
# Original Size Results for P59AA2AC.jpg:
# Dice Score: 0.9313
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2AE.jpg
#
# Original Size Results for P59AA2AE.jpg:
# Dice Score: 0.9483
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2AG.jpg
#
# Original Size Results for P59AA2AG.jpg:
# Dice Score: 0.9459
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2AI.jpg
#
# Original Size Results for P59AA2AI.jpg:
# Dice Score: 0.9257
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2AK.jpg
#
# Original Size Results for P59AA2AK.jpg:
# Dice Score: 0.9658
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2B0.jpg
#
# Original Size Results for P59AA2B0.jpg:
# Dice Score: 0.9465
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2B2.jpg
#
# Original Size Results for P59AA2B2.jpg:
# Dice Score: 0.9346
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2B4.jpg
#
# Original Size Results for P59AA2B4.jpg:
# Dice Score: 0.9477
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2B6.jpg
#
# Original Size Results for P59AA2B6.jpg:
# Dice Score: 0.9476
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2B8.jpg
#
# Original Size Results for P59AA2B8.jpg:
# Dice Score: 0.9530
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2BA.jpg
#
# Original Size Results for P59AA2BA.jpg:
# Dice Score: 0.9666
# /root/autodl-tmp/new_test_dataset/imgs/P59AA2BC.jpg
#
# Original Size Results for P59AA2BC.jpg:
# Dice Score: 0.9595
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSK0.jpg
#
# Original Size Results for P59BOSK0.jpg:
# Dice Score: 0.9521
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSK2.jpg
#
# Original Size Results for P59BOSK2.jpg:
# Dice Score: 0.9469
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSK4.jpg
#
# Original Size Results for P59BOSK4.jpg:
# Dice Score: 0.9369
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSK6.jpg
#
# Original Size Results for P59BOSK6.jpg:
# Dice Score: 0.9610
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSK8.jpg
#
# Original Size Results for P59BOSK8.jpg:
# Dice Score: 0.9662
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSKA.jpg
#
# Original Size Results for P59BOSKA.jpg:
# Dice Score: 0.9524
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSKC.jpg
#
# Original Size Results for P59BOSKC.jpg:
# Dice Score: 0.9582
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSKI.jpg
#
# Original Size Results for P59BOSKI.jpg:
# Dice Score: 0.9484
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSKO.jpg
#
# Original Size Results for P59BOSKO.jpg:
# Dice Score: 0.9755
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSKQ.jpg
#
# Original Size Results for P59BOSKQ.jpg:
# Dice Score: 0.9605
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSKS.jpg
#
# Original Size Results for P59BOSKS.jpg:
# Dice Score: 0.9595
# /root/autodl-tmp/new_test_dataset/imgs/P59BOSKU.jpg
#
# Original Size Results for P59BOSKU.jpg:
# Dice Score: 0.9474
# /root/autodl-tmp/new_test_dataset/imgs/P5CB5QIS.jpg
#
# Original Size Results for P5CB5QIS.jpg:
# Dice Score: 0.9632
# /root/autodl-tmp/new_test_dataset/imgs/P5CB5QIU.jpg
#
# Original Size Results for P5CB5QIU.jpg:
# Dice Score: 0.9621
# /root/autodl-tmp/new_test_dataset/imgs/P5CB5QJ4.jpg
#
# Original Size Results for P5CB5QJ4.jpg:
# Dice Score: 0.9600
# /root/autodl-tmp/new_test_dataset/imgs/P5CB5QJ6.jpg
#
# Original Size Results for P5CB5QJ6.jpg:
# Dice Score: 0.9482
# /root/autodl-tmp/new_test_dataset/imgs/P5CB5QJC.jpg
#
# Original Size Results for P5CB5QJC.jpg:
# Dice Score: 0.9616
# /root/autodl-tmp/new_test_dataset/imgs/P5CB5QJE.jpg
#
# Original Size Results for P5CB5QJE.jpg:
# Dice Score: 0.9337
# /root/autodl-tmp/new_test_dataset/imgs/P5CET82O.jpg
#
# Original Size Results for P5CET82O.jpg:
# Dice Score: 0.9461
# /root/autodl-tmp/new_test_dataset/imgs/P5CET82Q.jpg
#
# Original Size Results for P5CET82Q.jpg:
# Dice Score: 0.9405
# /root/autodl-tmp/new_test_dataset/imgs/P5CET832.jpg
#
# Original Size Results for P5CET832.jpg:
# Dice Score: 0.9540
# /root/autodl-tmp/new_test_dataset/imgs/P5CET83I.jpg
#
# Original Size Results for P5CET83I.jpg:
# Dice Score: 0.9540
# /root/autodl-tmp/new_test_dataset/imgs/P5CET83M.jpg
#
# Original Size Results for P5CET83M.jpg:
# Dice Score: 0.9422
# /root/autodl-tmp/new_test_dataset/imgs/P5CET83Q.jpg
#
# Original Size Results for P5CET83Q.jpg:
# Dice Score: 0.9050
# /root/autodl-tmp/new_test_dataset/imgs/P5CET83S.jpg
#
# Original Size Results for P5CET83S.jpg:
# Dice Score: 0.9616
# /root/autodl-tmp/new_test_dataset/imgs/P5E97RO8.jpg
#
# Original Size Results for P5E97RO8.jpg:
# Dice Score: 0.9569
# /root/autodl-tmp/new_test_dataset/imgs/P5E97ROA.jpg
#
# Original Size Results for P5E97ROA.jpg:
# Dice Score: 0.9475
# /root/autodl-tmp/new_test_dataset/imgs/P5E97ROC.jpg
#
# Original Size Results for P5E97ROC.jpg:
# Dice Score: 0.9443
# /root/autodl-tmp/new_test_dataset/imgs/P5E97ROE.jpg
#
# Original Size Results for P5E97ROE.jpg:
# Dice Score: 0.9708
# /root/autodl-tmp/new_test_dataset/imgs/P5E97ROQ.jpg
#
# Original Size Results for P5E97ROQ.jpg:
# Dice Score: 0.9629
# /root/autodl-tmp/new_test_dataset/imgs/P5E97ROS.jpg
#
# Original Size Results for P5E97ROS.jpg:
# Dice Score: 0.9490
# /root/autodl-tmp/new_test_dataset/imgs/P5E97ROU.jpg
#
# Original Size Results for P5E97ROU.jpg:
# Dice Score: 0.9300
# /root/autodl-tmp/new_test_dataset/imgs/P5E97RP0.jpg
#
# Original Size Results for P5E97RP0.jpg:
# Dice Score: 0.9646
# /root/autodl-tmp/new_test_dataset/imgs/P5E97RP2.jpg
#
# Original Size Results for P5E97RP2.jpg:
# Dice Score: 0.9596
# /root/autodl-tmp/new_test_dataset/imgs/P5E9FLHE.jpg
#
# Original Size Results for P5E9FLHE.jpg:
# Dice Score: 0.9422
# /root/autodl-tmp/new_test_dataset/imgs/P5E9FLHG.jpg
#
# Original Size Results for P5E9FLHG.jpg:
# Dice Score: 0.9410
# /root/autodl-tmp/new_test_dataset/imgs/P5E9FLHI.jpg
#
# Original Size Results for P5E9FLHI.jpg:
# Dice Score: 0.9413
# /root/autodl-tmp/new_test_dataset/imgs/P5E9FLHK.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 258
#     255 original_img, original_mask, original_size = load_original_image_mask(img_path, mask_path, rf_path)
#     257 img_tensor = preprocess_image(img_path)
# --> 258 rf_tensor = load_rf_image(rf_path)
#     260 with torch.no_grad():
#     261     pred = model(img_tensor, None)
#
# Cell In[1], line 214, in load_rf_image(rfimg_path, img_size)
#     208 """加载并处理RF图像（保持单通道），返回归一化后的RF数据和tensor"""
#     209 rf_transform = transforms.Compose([
#     210     transforms.ToPILImage(),
#     211     transforms.Resize((224, 224)),
#     212     transforms.ToTensor()
#     213 ])
# --> 214 mat_data = sio.loadmat(rfimg_path)
#     215 frameRF = mat_data['frameRF']
#     216 rf_data = frameRF[0]['data'][0]
#
# File ~/miniconda3/lib/python3.10/site-packages/scipy/io/matlab/_mio.py:235, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#     233 with _open_file_context(file_name, appendmat) as f:
#     234     MR, _ = mat_reader_factory(f, **kwargs)
# --> 235     matfile_dict = MR.get_variables(variable_names)
#     236 if spmatrix:
#     237     from scipy.sparse import issparse, coo_matrix
#
# File ~/miniconda3/lib/python3.10/site-packages/scipy/io/matlab/_mio5.py:333, in MatFile5Reader.get_variables(self, variable_names)
#     331     continue
#     332 try:
# --> 333     res = self.read_var_array(hdr, process)
#     334 except MatReadError as err:
#     335     warnings.warn(
#     336         f'Unreadable variable "{name}", because "{err}"',
#     337         Warning, stacklevel=2)
#
# File ~/miniconda3/lib/python3.10/site-packages/scipy/io/matlab/_mio5.py:291, in MatFile5Reader.read_var_array(self, header, process)
#     274 def read_var_array(self, header, process=True):
#     275     ''' Read array, given `header`
#     276
#     277     Parameters
#    (...)
#     289        `process`.
#     290     '''
# --> 291     return self._matrix_reader.array_from_header(header, process)
#
# File _mio5_utils.pyx:665, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File _mio5_utils.pyx:712, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File _mio5_utils.pyx:954, in scipy.io.matlab._mio5_utils.VarReader5.read_struct()
#
# File _mio5_utils.pyx:663, in scipy.io.matlab._mio5_utils.VarReader5.read_mi_matrix()
#
# File _mio5_utils.pyx:706, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File _mio5_utils.pyx:865, in scipy.io.matlab._mio5_utils.VarReader5.read_char()
#
# KeyboardInterrupt:

# %%
# import os
# import shutil
# from pathlib import Path

# def merge_datasets(source_dirs, target_dir):
#     """
#     将多个源目录中的内容合并到目标目录中
    
#     参数:
#         source_dirs: 源目录列表
#         target_dir: 目标目录
#     """
#     # 确保目标目录存在
#     os.makedirs(target_dir, exist_ok=True)
    
#     # 遍历所有源目录
#     for src_dir in source_dirs:
#         if not os.path.exists(src_dir):
#             print(f"警告: 源目录不存在: {src_dir}")
#             continue
            
#         # 遍历源目录中的所有文件和子目录
#         for root, dirs, files in os.walk(src_dir):
#             # 计算相对于源目录的相对路径
#             rel_path = os.path.relpath(root, src_dir)
#             target_path = os.path.join(target_dir, rel_path)
            
#             # 创建对应的目标子目录
#             os.makedirs(target_path, exist_ok=True)
            
#             # 复制所有文件
#             for file in files:
#                 src_file = os.path.join(root, file)
#                 dst_file = os.path.join(target_path, file)
                
#                 # 如果目标文件已存在，可以选择跳过或覆盖
#                 if os.path.exists(dst_file):
#                     print(f"警告: 文件已存在，将被覆盖: {dst_file}")
                
#                 shutil.copy2(src_file, dst_file)
#                 print(f"已复制: {src_file} -> {dst_file}")

# def main():
#     # 定义文件夹结构
#     folders = ['binary_masks', 'masks', 'imgs', 'rfs']
#     base_train = '/root/autodl-tmp/data'
#     base_test = '/root/autodl-tmp/test_dataset'
#     base_new_train = '/root/autodl-tmp/new_test_dataset'
    
#     # 为每个文件夹执行合并操作
#     for folder in folders:
#         print(f"\n正在处理文件夹: {folder}")
        
#         # 源目录列表
#         source_dirs = [
#             os.path.join(base_train, folder),
#             os.path.join(base_test, folder)
#         ]
        
#         # 目标目录
#         target_dir = os.path.join(base_new_train, folder)
        
#         # 执行合并
#         merge_datasets(source_dirs, target_dir)
    
#     print("\n所有文件夹合并完成!")

# main()
# Out:
# 正在处理文件夹: binary_masks
# 已复制: /root/autodl-tmp/data/binary_masks/OCHADNGK.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHADNGK.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHADNP4.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHADNP4.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHALB1C.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHALB1C.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHALB1G.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHALB1G.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHALB1K.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHALB1K.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHF8JA8.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHF8JA8.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHF8JAC.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHF8JAC.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHF8JAI.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHF8JAI.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHF8JAM.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHF8JAM.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHFHDQU.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHFHDQU.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHFHDR2.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHFHDR2.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHFHDR6.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHFHDR6.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCHFHDRC.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCHFHDRC.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8KD0K.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8KD0K.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8KD0O.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8KD0O.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8KD0U.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8KD0U.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8KD92.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8KD92.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8MGHC.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8MGHC.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8MGHG.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8MGHG.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8MGPK.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8MGPK.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI8MGPO.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI8MGPO.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI9IMJK.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI9IMJK.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI9IMJO.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI9IMJO.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI9IMK8.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI9IMK8.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI9IMKC.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI9IMKC.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI9SGCO.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI9SGCO.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI9SGCS.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI9SGCS.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCI9SGD8.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCI9SGD8.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCIAIG66.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCIAIG66.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCIAIG82.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCIAIG82.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCIAIG8E.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCIAIG8E.png
# 已复制: /root/autodl-tmp/data/binary_masks/OCIAIG8I.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./OCIAIG8I.png
# 已复制: /root/autodl-tmp/data/binary_masks/P1Q92O8A.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P1Q92O8A.png
# 已复制: /root/autodl-tmp/data/binary_masks/P27AJ4II.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P27AJ4II.png
# 已复制: /root/autodl-tmp/data/binary_masks/P27AJ4IS.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P27AJ4IS.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2EEJTP2.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2EEJTP2.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2EEJTP4.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2EEJTP4.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2HB233Q.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2HB233Q.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2K8O3H6.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2K8O3H6.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2K8O3HI.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2K8O3HI.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2KAOS3C.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2KAOS3C.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2KAOS3M.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2KAOS3M.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2KBNKK2.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2KBNKK2.png
# 已复制: /root/autodl-tmp/data/binary_masks/P2KBNKKE.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P2KBNKKE.png
# 已复制: /root/autodl-tmp/data/binary_masks/P338O00A.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P338O00A.png
# 已复制: /root/autodl-tmp/data/binary_masks/P338O00M.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P338O00M.png
# 已复制: /root/autodl-tmp/data/binary_masks/P33AD4L0.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P33AD4L0.png
# 已复制: /root/autodl-tmp/data/binary_masks/P33AD4LC.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./P33AD4LC.png
# 已复制: /root/autodl-tmp/data/binary_masks/P359OT3M.png -> /root/autodl-tmp/new_test_dataset/binary_masks/./